# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17075, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 17075 (delta 29), reused 34 (delta 17), pack-reused 17022 (from 1)
# Receiving objects: 100% (17075/17075), 15.69 MiB | 34.32 MiB/s, done.
# Resolving deltas: 100% (11724/11724), done.

# %%
# %cd yolov5
# Out:
# /kaggle/working/yolov5

# %%
# !pip install -r requirements.txt

# %%
# %%writefile /kaggle/working/data.yaml
# path: /kaggle/input/fire-detection-in-yolo-format
# train: train/images
# val: valid/images
# test: test/images
#
# nc: 1
# names: ['fire']
# Out:
# Writing /kaggle/working/data.yaml

# %%
# !python train.py --img 416 \
                 --batch 16 \
                 --epochs 100 \
                 --data /kaggle/working/data.yaml \
                 --cfg models/yolov5s.yaml \
                 --weights yolov5s.pt \
                 --name fire_detection_model
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...
